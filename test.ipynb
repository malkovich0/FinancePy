# %%
from finance import *

case_active = Finance()
case_defensive = Finance()

# %%
case_active.methodStockWeight='momentum_score_active'

# %%
case_active.caseStudy()
# Out:
# 2012-04-15 00:00:00 2
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# 2012-06-15 00:00:00 3
# 2012-09-15 00:00:00 3
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# 2012-12-15 00:00:00 4
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.
# 2013-04-15 00:00:00 2
# 2013-06-15 00:00:00 3
# The date you entered 20130615 seems to be a holiday. PYKRX changes the date parameter to 20130614 to query the requested information.
# The date you entered 20130615 seems to be a holiday. PYKRX changes the date parameter to 20130614 to query the requested information.
# 2013-09-15 00:00:00 3
# The date you entered 20130915 seems to be a holiday. PYKRX changes the date parameter to 20130913 to query the requested information.
# The date you entered 20130915 seems to be a holiday. PYKRX changes the date parameter to 20130913 to query the requested information.
# 2013-12-15 00:00:00 4
# The date you entered 20131215 seems to be a holiday. PYKRX changes the date parameter to 20131213 to query the requested information.
# The date you entered 20131215 seems to be a holiday. PYKRX changes the date parameter to 20131213 to query the requested information.
# 2014-04-15 00:00:00 2
# 2014-06-15 00:00:00 3
# The date you entered 20140615 seems to be a holiday. PYKRX changes the date parameter to 20140613 to query the requested information.
# The date you entered 20140615 seems to be a holiday. PYKRX changes the date parameter to 20140613 to query the requested information.
# 2014-09-15 00:00:00 3
# 2014-12-15 00:00:00 4
# 2015-04-15 00:00:00 2
# 2015-06-15 00:00:00 3
# 2015-09-15 00:00:00 3
# 2015-12-15 00:00:00 4
# 2016-04-15 00:00:00 2
# 2016-06-15 00:00:00 3
# 2016-09-15 00:00:00 3
# The date you entered 20160915 seems to be a holiday. PYKRX changes the date parameter to 20160913 to query the requested information.
# The date you entered 20160915 seems to be a holiday. PYKRX changes the date parameter to 20160913 to query the requested information.
# 2016-12-15 00:00:00 4
# 2017-04-15 00:00:00 2
# The date you entered 20170415 seems to be a holiday. PYKRX changes the date parameter to 20170414 to query the requested information.
# The date you entered 20170415 seems to be a holiday. PYKRX changes the date parameter to 20170414 to query the requested information.
# 2017-06-15 00:00:00 3
# 2017-09-15 00:00:00 3
# 2017-12-15 00:00:00 4
# 2018-04-15 00:00:00 2
# The date you entered 20180415 seems to be a holiday. PYKRX changes the date parameter to 20180413 to query the requested information.
# The date you entered 20180415 seems to be a holiday. PYKRX changes the date parameter to 20180413 to query the requested information.
# 2018-06-15 00:00:00 3
# 2018-09-15 00:00:00 3
# The date you entered 20180915 seems to be a holiday. PYKRX changes the date parameter to 20180914 to query the requested information.
# The date you entered 20180915 seems to be a holiday. PYKRX changes the date parameter to 20180914 to query the requested information.
# 2018-12-15 00:00:00 4
# The date you entered 20181215 seems to be a holiday. PYKRX changes the date parameter to 20181214 to query the requested information.
# The date you entered 20181215 seems to be a holiday. PYKRX changes the date parameter to 20181214 to query the requested information.
# 2019-04-15 00:00:00 2
# 2019-06-15 00:00:00 3
# The date you entered 20190615 seems to be a holiday. PYKRX changes the date parameter to 20190614 to query the requested information.
# The date you entered 20190615 seems to be a holiday. PYKRX changes the date parameter to 20190614 to query the requested information.
# 2019-09-15 00:00:00 3
# The date you entered 20190915 seems to be a holiday. PYKRX changes the date parameter to 20190911 to query the requested information.
# The date you entered 20190915 seems to be a holiday. PYKRX changes the date parameter to 20190911 to query the requested information.
# 2019-12-15 00:00:00 4
# The date you entered 20191215 seems to be a holiday. PYKRX changes the date parameter to 20191213 to query the requested information.
# The date you entered 20191215 seems to be a holiday. PYKRX changes the date parameter to 20191213 to query the requested information.
# 2020-04-15 00:00:00 2
# The date you entered 20200415 seems to be a holiday. PYKRX changes the date parameter to 20200414 to query the requested information.
# The date you entered 20200415 seems to be a holiday. PYKRX changes the date parameter to 20200414 to query the requested information.
# 2020-06-15 00:00:00 3
# 2020-09-15 00:00:00 3
# 2020-12-15 00:00:00 4

# %%
case_defensive.caseStudy()
# Out:
# 2012-04-15 00:00:00 2
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# 2012-06-15 00:00:00 3
# 2012-09-15 00:00:00 3
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# 2012-12-15 00:00:00 4
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.
# 2013-04-15 00:00:00 2
# 2013-06-15 00:00:00 3
# The date you entered 20130615 seems to be a holiday. PYKRX changes the date parameter to 20130614 to query the requested information.
# The date you entered 20130615 seems to be a holiday. PYKRX changes the date parameter to 20130614 to query the requested information.
# 2013-09-15 00:00:00 3
# The date you entered 20130915 seems to be a holiday. PYKRX changes the date parameter to 20130913 to query the requested information.
# The date you entered 20130915 seems to be a holiday. PYKRX changes the date parameter to 20130913 to query the requested information.
# 2013-12-15 00:00:00 4
# The date you entered 20131215 seems to be a holiday. PYKRX changes the date parameter to 20131213 to query the requested information.
# The date you entered 20131215 seems to be a holiday. PYKRX changes the date parameter to 20131213 to query the requested information.
# 2014-04-15 00:00:00 2
# 2014-06-15 00:00:00 3
# The date you entered 20140615 seems to be a holiday. PYKRX changes the date parameter to 20140613 to query the requested information.
# The date you entered 20140615 seems to be a holiday. PYKRX changes the date parameter to 20140613 to query the requested information.
# 2014-09-15 00:00:00 3
# 2014-12-15 00:00:00 4
# 2015-04-15 00:00:00 2
# 2015-06-15 00:00:00 3
# 2015-09-15 00:00:00 3
# 2015-12-15 00:00:00 4
# 2016-04-15 00:00:00 2
# 2016-06-15 00:00:00 3
# 2016-09-15 00:00:00 3
# The date you entered 20160915 seems to be a holiday. PYKRX changes the date parameter to 20160913 to query the requested information.
# The date you entered 20160915 seems to be a holiday. PYKRX changes the date parameter to 20160913 to query the requested information.
# 2016-12-15 00:00:00 4
# 2017-04-15 00:00:00 2
# The date you entered 20170415 seems to be a holiday. PYKRX changes the date parameter to 20170414 to query the requested information.
# The date you entered 20170415 seems to be a holiday. PYKRX changes the date parameter to 20170414 to query the requested information.
# 2017-06-15 00:00:00 3
# 2017-09-15 00:00:00 3
# 2017-12-15 00:00:00 4
# 2018-04-15 00:00:00 2
# The date you entered 20180415 seems to be a holiday. PYKRX changes the date parameter to 20180413 to query the requested information.
# The date you entered 20180415 seems to be a holiday. PYKRX changes the date parameter to 20180413 to query the requested information.
# 2018-06-15 00:00:00 3
# 2018-09-15 00:00:00 3
# The date you entered 20180915 seems to be a holiday. PYKRX changes the date parameter to 20180914 to query the requested information.
# The date you entered 20180915 seems to be a holiday. PYKRX changes the date parameter to 20180914 to query the requested information.
# 2018-12-15 00:00:00 4
# The date you entered 20181215 seems to be a holiday. PYKRX changes the date parameter to 20181214 to query the requested information.
# The date you entered 20181215 seems to be a holiday. PYKRX changes the date parameter to 20181214 to query the requested information.
# 2019-04-15 00:00:00 2
# 2019-06-15 00:00:00 3
# The date you entered 20190615 seems to be a holiday. PYKRX changes the date parameter to 20190614 to query the requested information.
# The date you entered 20190615 seems to be a holiday. PYKRX changes the date parameter to 20190614 to query the requested information.
# 2019-09-15 00:00:00 3
# The date you entered 20190915 seems to be a holiday. PYKRX changes the date parameter to 20190911 to query the requested information.
# The date you entered 20190915 seems to be a holiday. PYKRX changes the date parameter to 20190911 to query the requested information.
# 2019-12-15 00:00:00 4
# The date you entered 20191215 seems to be a holiday. PYKRX changes the date parameter to 20191213 to query the requested information.
# The date you entered 20191215 seems to be a holiday. PYKRX changes the date parameter to 20191213 to query the requested information.
# 2020-04-15 00:00:00 2
# The date you entered 20200415 seems to be a holiday. PYKRX changes the date parameter to 20200414 to query the requested information.
# The date you entered 20200415 seems to be a holiday. PYKRX changes the date parameter to 20200414 to query the requested information.
# 2020-06-15 00:00:00 3
# 2020-09-15 00:00:00 3
# 2020-12-15 00:00:00 4

# %%
import pickle
import json

# %%
case_defensive.change
# Out:
#               095570    006840    152100    295820    253150    253160  \
# Date
# 1990-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2021-08-18 -0.008130  0.009766  0.005504  0.008525  0.009531 -0.009569
# 2021-08-19 -0.034426 -0.048356 -0.020231 -0.031699 -0.039355  0.039855
# 2021-08-20 -0.033956 -0.012195 -0.008502 -0.019642 -0.020870  0.018583
# 2021-08-23  0.019332  0.022634  0.009188  0.019590  0.029886 -0.017104
# 2021-08-24  0.022414  0.030181  0.016023  0.020087  0.024091 -0.033643
#
#               395750    395760    278420    292750  ...  014590.1  021060.1  \
# Date                                                ...
# 1990-01-03       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1990-01-04       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1990-01-05       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1990-01-06       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1990-01-08       NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2021-08-18  0.002074  0.005152  0.006234  0.006062  ...       NaN       NaN
# 2021-08-19 -0.020693 -0.022040 -0.026329 -0.020435  ...       NaN       NaN
# 2021-08-20 -0.016376 -0.016247 -0.016437 -0.010965  ...       NaN       NaN
# 2021-08-23  0.015575  0.016516  0.015094  0.010817  ...       NaN       NaN
# 2021-08-24  0.017451  0.012055  0.015401  0.016586  ...       NaN       NaN
#
#             027840.1  024870.1  013200.1  024100.1  021960.1  016560.1  \
# Date
# 1990-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2021-08-18       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-08-19       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-08-20       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-08-23       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-08-24       NaN       NaN       NaN       NaN       NaN       NaN
#
#             007800.1  013240.1
# Date
# 1990-01-03       NaN       NaN
# 1990-01-04       NaN       NaN
# 1990-01-05       NaN       NaN
# 1990-01-06       NaN       NaN
# 1990-01-08       NaN       NaN
# ...              ...       ...
# 2021-08-18       NaN       NaN
# 2021-08-19       NaN       NaN
# 2021-08-20       NaN       NaN
# 2021-08-23       NaN       NaN
# 2021-08-24       NaN       NaN
#
# [8234 rows x 3975 columns]

# %%
with open('Raw_Finance/finance_naver_converted.pickle','wb') as handle:
    pickle.dump(test, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('Raw_Price/change_all.pickle','rb') as handle:
#     cases = pickle.load(handle)
# cases

# %%
defensive = case_active.simple_analyzer_monthly_return(data=cases['withMomentumYear'])

# %%
active['Buy']
# Out:
#             1         2         3         4         5         6         7   \
# 2012       NaN       NaN       NaN  1.041573  0.943195  1.029146  1.012044
# 2013  1.044872  1.053713  1.082789  1.115881  0.985997  0.946393  1.053660
# 2014  1.074857  1.091464  1.106853  1.068005  1.075723  1.004399  1.060622
# 2015  1.066990  1.069893  1.105618  1.068433  1.055890  0.992008  1.001625
# 2016  0.924913  1.022284  1.082257  0.993295  1.005741  1.012724  1.068501
# 2017  1.015915  0.987469  1.108766  0.967148  1.078437  1.022155  0.960146
# 2018  1.138840  0.955839  1.024199  0.997809  1.046187  0.910293  0.963947
# 2019  1.245730  0.929201  1.027757  1.044124  0.940639  1.044713  0.891853
# 2020  0.964937  0.914817  0.919968  1.045124  1.166053  0.952854  1.147653
# 2021  0.987384  1.065126  1.151379  1.031544       NaN       NaN       NaN
#
#             8         9         10        11        12
# 2012  1.112810  1.117873  1.038124  1.048723  1.024723
# 2013  0.977896  1.048486  0.998678  1.017148  0.970575
# 2014  0.986720  1.021793  0.969712  0.942360  1.027118
# 2015  0.941661  1.041600  0.975489  0.970254  0.977558
# 2016  0.975934  1.052229  0.975141  1.032473  1.017324
# 2017  1.037173  0.958409  1.001126  1.054838  1.018300
# 2018  1.002458  1.080891  0.825603  1.037659  0.984824
# 2019  1.031554  1.061105  0.953369  0.992895  1.110214
# 2020  1.054711  0.946243  0.965192  1.142888  1.038426
# 2021       NaN       NaN       NaN       NaN       NaN

# %%
defensive['Buy']
# Out:
#             1         2         3         4         5         6         7   \
# 2012       NaN       NaN       NaN  1.031873  0.957419  1.020457  1.008455
# 2013  1.037562  1.040240  1.064395  1.102811  0.986990  0.950882  1.043485
# 2014  1.049787  1.065120  1.078407  1.058682  1.068509  1.004225  1.050064
# 2015  1.049045  1.050399  1.083685  1.058926  1.052027  0.992137  1.002332
# 2016  0.961811  0.998095  1.030587  0.998940  1.003691  1.008807  1.047545
# 2017  1.008873  0.992914  1.060526  0.979717  1.049366  1.014212  0.971815
# 2018  1.081353  0.973017  1.013708  0.998704  1.027996  0.929623  0.979731
# 2019  1.091924  0.958207  1.015194  1.019818  0.962194  1.027716  0.943258
# 2020  0.979001  0.961918  0.927412  1.006893  1.061875  0.978402  1.093268
# 2021  0.988042  1.054036  1.114063  1.023906       NaN       NaN       NaN
#
#             8         9         10        11        12
# 2012  1.077477  1.086863  1.030739  1.033843  1.017801
# 2013  0.982628  1.036581  0.998794  1.010860  0.980834
# 2014  0.990351  1.018206  0.973182  0.957350  1.016976
# 2015  0.961625  1.027177  0.982388  0.975284  0.989289
# 2016  0.982205  1.036239  0.984314  1.019622  1.009853
# 2017  1.019156  0.970712  0.999578  1.029053  1.010853
# 2018  1.001287  1.041975  0.914333  1.011452  0.993871
# 2019  1.012435  1.029559  0.974063  0.993978  1.050404
# 2020  1.040670  0.954749  0.974891  1.111145  1.030916
# 2021       NaN       NaN       NaN       NaN       NaN

# %%
analyze_result_rar
# Out:
#             1         2         3         4         5         6         7   \
# 2012 -0.156997 -0.137797 -0.125221 -0.081641 -0.031511 -0.019930  0.011165
# 2013 -0.018080 -0.004999  0.029421  0.060076  0.077048  0.059768  0.009632
# 2014  0.016052  0.011899  0.024039  0.033946  0.036682  0.053472  0.029048
# 2015 -0.001060 -0.024708 -0.032194 -0.016713  0.012318  0.034065  0.042774
# 2016 -0.032530 -0.083076 -0.100757 -0.088283 -0.057601 -0.032897 -0.010180
# 2017  0.064305  0.057320  0.052795  0.074013  0.103923  0.153861  0.191921
# 2018  0.243421  0.209988  0.155841  0.100549  0.060376  0.036276 -0.006566
# 2019 -0.211775 -0.201486 -0.177657 -0.148557 -0.107208 -0.083050 -0.068998
# 2020 -0.039463 -0.004691 -0.002089 -0.067629 -0.071640 -0.056562 -0.014205
# 2021  0.408551  0.570258  0.827501  0.748155  0.706565  0.619348  0.572464
#
#             8         9         10        11        12
# 2012  0.046775  0.035514  0.015033  0.004746 -0.009093
# 2013 -0.026393 -0.033235 -0.011018  0.001717  0.005450
# 2014  0.023778  0.021342  0.022537  0.018942  0.017958
# 2015  0.055391  0.038836  0.039849  0.027962  0.008533
# 2016  0.021239  0.023236  0.036182  0.055937  0.059257
# 2017  0.228416  0.251413  0.268270  0.295495  0.271505
# 2018 -0.049318 -0.097838 -0.118527 -0.159823 -0.191051
# 2019 -0.071847 -0.065561 -0.045240 -0.046654 -0.048624
# 2020  0.038822  0.078754  0.120543  0.169584  0.271998
# 2021  0.474006  0.423313  0.393409  0.272114  0.162042

# %%
analyze_result_r2
# Out:
#             1         2         3         4         5         6         7   \
# 2012  0.438764  0.332059  0.263590  0.134437  0.025026  0.010372  0.004218
# 2013  0.019395  0.001761  0.064740  0.299894  0.468508  0.326964  0.007705
# 2014  0.026565  0.013620  0.061171  0.112847  0.132997  0.247741  0.119109
# 2015  0.000155  0.086302  0.142639  0.036591  0.012822  0.081515  0.123767
# 2016  0.066942  0.378291  0.549980  0.492710  0.280774  0.116471  0.014170
# 2017  0.489729  0.484337  0.489396  0.585439  0.649637  0.668035  0.718632
# 2018  0.858375  0.782287  0.649732  0.463835  0.344821  0.170940  0.004185
# 2019  0.856349  0.796490  0.715670  0.571135  0.405187  0.331212  0.246290
# 2020  0.084001  0.001268  0.000211  0.091947  0.089475  0.054324  0.003373
# 2021  0.654604  0.843781  0.930112  0.925571  0.921096  0.911470  0.892297
#
#             8         9         10        11        12
# 2012  0.075863  0.046070  0.011075  0.001249  0.004624
# 2013  0.086931  0.137062  0.013156  0.000263  0.002828
# 2014  0.092510  0.086477  0.094646  0.059487  0.053021
# 2015  0.217731  0.096894  0.091214  0.047462  0.004433
# 2016  0.061365  0.070246  0.165321  0.398325  0.434861
# 2017  0.801352  0.859388  0.898433  0.923653  0.903973
# 2018  0.158462  0.536603  0.713451  0.746030  0.803206
# 2019  0.241778  0.215251  0.125908  0.125352  0.132426
# 2020  0.017567  0.068072  0.140494  0.254504  0.452505
# 2021  0.844331  0.761222  0.700007  0.632348  0.524296

# %%
activeMinusDefensive = [a-b for a,b in zip(list(active['Buy'].T[2012][3:]),list(defensive['Buy'].T[2012][3:]))]
for i in range(2013,2021):
    activeMinusDefensive += [a-b for a,b in zip(list(active['Buy'].T[i]),list(defensive['Buy'].T[i]))]
activeMinusDefensive += [a-b for a,b in zip(list(active['Buy'].T[2021][:4]),list(defensive['Buy'].T[2021][:4]))]
len(activeMinusDefensive)
# Out:
# 109

# %%
rar_list = [a*b for a,b in zip(list(analyze_result_rar.T[2012][3:]),list(analyze_result_r2.T[2012][3:]))]
for i in range(2013,2021):
    rar_list += [a*b for a,b in zip(list(analyze_result_rar.T[i]),list(analyze_result_r2.T[i]))]
rar_list += [a*b for a,b in zip(list(analyze_result_rar.T[2021][:4]),list(analyze_result_r2.T[2021][:4]))]
len(rar_list)
# Out:
# 109

# %%
rar_list = list(analyze_result_rar.T[2012][3:])
for i in range(2013,2021):
    rar_list += list(analyze_result_rar.T[i])
rar_list += list(analyze_result_rar.T[2021][:4])
len(rar_list)
# Out:
# 109

# %%
plt.scatter(rar_list, activeMinusDefensive, c='green')
# plt.scatter(rar_list, defensive_list, c='red')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(rar_list, active_list, c='green')
plt.scatter(rar_list, defensive_list, c='red')
plt.show()

# %%
plt.scatter(rar_list, active_list, c='green')
plt.scatter(rar_list, defensive_list, c='red')
plt.show()

# %%
pd.DataFrame({'active':active_list,'defensive':defensive_list}).corr()
# Out:
#              active  defensive
# active     1.000000   0.958569
# defensive  0.958569   1.000000

# %%
# 매월 15일 기준 이전 1년 동안의 RAR
data = case_active.kospi_index

# %%
import FinanceDataReader as fdr
data_temp = fdr.DataReader('KS11')

# %%
data
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 1981-05-01   123.60   123.60   123.60   123.60    3330000.0  0.0098
# 1981-05-02   123.50   123.50   123.50   123.50    2040000.0 -0.0008
# 1981-05-04   120.60   120.60   120.60   120.60    1930000.0 -0.0235
# 1981-05-06   120.70   120.70   120.70   120.70    1690000.0  0.0008
# 1981-05-07   119.30   119.30   119.30   119.30    1480000.0 -0.0116
# ...             ...      ...      ...      ...          ...     ...
# 2021-08-24  3138.30  3119.70  3142.58  3115.23  586530000.0  0.0156
# 2021-08-25  3146.81  3148.13  3161.00  3124.25  624690000.0  0.0027
# 2021-08-26  3128.53  3151.30  3159.37  3121.04  727720000.0 -0.0058
# 2021-08-27  3133.90  3116.29  3143.01  3106.97  520670000.0  0.0017
# 2021-08-30  3139.55  3160.87  3164.87  3132.77     488700.0  0.0018
#
# [10777 rows x 6 columns]

# %%
# year_range = range(data.index[0].year, data.index[-1].year + 1)
year_range = range(2012,2022)
month_range = range(1, 13)
analyze_result_monthly = {}
analyze_result_rar = pd.DataFrame(columns=month_range, index=year_range)
analyze_result_r2 = pd.DataFrame(columns=month_range, index=year_range)
for month in month_range:
    monthly_return_list_rar = []
    monthly_return_list_r2 = []
    for year in year_range:
        data_month = data.loc[datetime(year, month, 15)-relativedelta(years=1):datetime(year, month, 15), ['Change']]+1
        if len(data_month) == 0:
            return_month = float('nan')
        else:
            rar, r2 = case_active.calculateRegressedReturn(data_month['Change'])
        monthly_return_list_rar.append(rar[0][0])
        monthly_return_list_r2.append(r2)
    analyze_result_rar[month] = monthly_return_list_rar
    analyze_result_r2[month] = monthly_return_list_r2

# %%
case_active.calculateRegressedReturn(data.loc[datetime(2011,4,15):datetime(2012,4,15),'Change']+1)
# Out:
# (array([[-0.08164088]]), 0.1344374927860661)

# %%
a = (data.loc[datetime(2011,4,15):datetime(2012,4,15),'Change']+1).cumprod()
b = np.arange(249)/252
plt.scatter(b,a)
plt.show()

# %%
case_active.calculateRegressedReturn()

# %%
case_active.simple_analyzer_monthly_return(case_active.dictCaseStudy['withMomentumYear'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-833bc44c22be> in <module>
# ----> 1 case_active.simple_analyzer_monthly_return(case_active.dictCaseStudy['withMomentumYear'])
#
# ~\PycharmProjects\finance\finance.py in simple_analyzer_monthly_return(self, data)
#     622     def simple_analyzer_monthly_return(self, data: pd.DataFrame):
#     623         if not isinstance(data.index[0], datetime):
# --> 624             data.index = [date_to_date(date) for date in data.index]
#     625
#     626         year_range = range(data.index[0].year, data.index[-1].year + 1)
#
# ~\PycharmProjects\finance\finance.py in <listcomp>(.0)
#     622     def simple_analyzer_monthly_return(self, data: pd.DataFrame):
#     623         if not isinstance(data.index[0], datetime):
# --> 624             data.index = [date_to_date(date) for date in data.index]
#     625
#     626         year_range = range(data.index[0].year, data.index[-1].year + 1)
#
# NameError: name 'date_to_date' is not defined

# %%
case1.caseStudy()
# Out:
# 2012-04-15 00:00:00 2
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# 2012-06-15 00:00:00 3
# 2012-09-15 00:00:00 3
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# 2012-12-15 00:00:00 4
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.

# %%
test = case1.dictCaseStudy['withMomentumYear']['Buy']
list(test)
# Out:
# [1.007190334751641,
#  1.0013481111880145,
#  1.013438824545292,
#  1.004190230936959,
#  0.9905018930520129,
#  1.0094871739409281,
#  0.9984225870137935,
#  1.0044522219050065,
#  0.9950323200321927,
#  1.0123992537609148,
#  0.9952383510012144,
#  1.0133502516006019,
#  1.0004603318073464,
#  1.005296107076607,
#  0.9892266643931825,
#  1.0062844861758529,
#  1.0038625064810136,
#  0.9962341956648662,
#  0.9875599850618322,
#  0.9794632220297526,
#  0.9902650802883958,
#  0.9814446745453829,
#  1.0032935554823115,
#  0.9695680783398596,
#  1.0120196260285053,
#  1.0137034422916384,
#  0.9969867682272677,
#  1.0040000676860086,
#  1.010450541971083,
#  1.0054682855049923,
#  0.9996906117403147,
#  0.9893480527248252,
#  0.9961519011620337,
#  0.9714157375173416,
#  1.0154245317039652,
#  1.0095962024586318,
#  0.9989808219269948,
#  1.0204213090019514,
#  1.0014636915534465,
#  0.998381749196661,
#  1.0022012826038993,
#  0.9988651756951213,
#  1.0095857672842958,
#  0.9913475948808445,
#  1.0057461422070504,
#  0.9977624784063104,
#  0.9984166559307719,
#  1.00104854930873,
#  0.9978459283353398,
#  0.9984087826016327,
#  1.0047227795637297,
#  1.0033868743881516,
#  1.0004354298722404,
#  0.999058342786991,
#  1.0055448098540654,
#  1.0051801528366393,
#  0.9998335472658126,
#  1.0026072684736496,
#  0.989922994731639,
#  1.0020159445083308,
#  0.9911213187867051,
#  0.9967381731752816,
#  1.0090611146167117,
#  1.0021953174919431,
#  0.988923034203122,
#  1.0136331588921703,
#  1.006978161182997,
#  0.9944342434090686,
#  0.9965501965333512,
#  0.9862358445076891,
#  1.0126459173401359,
#  1.0074567757657125,
#  0.9955570821308151,
#  1.002880846711825,
#  1.0009654065776343,
#  0.9972166860261612,
#  0.9991750648481365,
#  0.9994731250482131,
#  1.0023559429397642,
#  1.0028188708407049,
#  1.0062755192482593,
#  1.0014780195398676,
#  0.9957711341376152,
#  1.0031652855932884,
#  1.0020431177727103,
#  1.0011054512086184,
#  1.0089956287256099,
#  1.0011818085975241,
#  1.002124823984429,
#  0.9976132279488447,
#  1.0001898236929052,
#  1.0053420514151292,
#  1.014996357201005,
#  1.01993481281278,
#  1.00125862802165,
#  1.0116254436770966,
#  1.0096235924216035,
#  0.9888520657580153,
#  0.9953422385449439,
#  1.000112773995612,
#  1.008302598806049,
#  1.00965492737463,
#  1.014804582012024,
#  1.0144903885394467,
#  1.0085589784266182,
#  1.0034759098693926,
#  1.0004082106930468,
#  1.0169434943456028,
#  1.0056078131174926,
#  0.9914615633246224,
#  1.0093994233847619,
#  1.0033038207506133,
#  0.9951060654929463,
#  0.9947702134805233,
#  1.004140107460615,
#  1.0097167378101886,
#  1.0085904912261923,
#  1.0041953675049835,
#  1.012758888249531,
#  1.0154151619936516,
#  0.9999010904881861,
#  0.9996055287899535,
#  0.9929224104757746,
#  1.0061611674014197,
#  0.9916085949428051,
#  1.0074287590159672,
#  1.0045073042733417,
#  0.9958875951408173,
#  0.9968686062100822,
#  1.0139800626874733,
#  1.005835851696501,
#  0.9922624048461434,
#  0.9898474528398923,
#  0.9907086363994658,
#  0.9878356092920367,
#  1.0015665513763983,
#  1.0131641298070728,
#  1.0084351780186056,
#  1.0044406766977096,
#  1.0038335379720664,
#  1.0083510618479123,
#  1.005194863742205,
#  1.0094197643682519,
#  1.0030922557221318,
#  0.9944899772981534,
#  0.9825963002594413,
#  0.9890576089677684,
#  0.998622083539134,
#  0.9907840181225078,
#  1.0114929404241906,
#  1.0011942135180258,
#  0.9987618704158375,
#  1.011589747609257,
#  1.0034285727791021,
#  1.001266319342443,
#  0.9919278162378807,
#  0.9970485266050296,
#  1.0090875965743777,
#  1.0098571498015676,
#  0.9965528257297405,
#  1.007355603286074,
#  1.002020119414058,
#  0.993132934848459,
#  0.99605083698296,
#  1.0032999972018226,
#  0.9941150875551076,
#  1.0063508623896174,
#  1.0084213121087677,
#  1.0028934638832423,
#  0.9958718212954416,
#  0.997860122981419,
#  1.0002206091766226,
#  0.995769191612328,
#  1.005989416227373,
#  1.0039753980430108,
#  1.0066754597652703,
#  1.0013066915189368,
#  1.0075573597505405,
#  1.0010928296968047,
#  1.0065225650532557,
#  1.0055225079384433,
#  1.0051897828359042,
#  1.0055883546511524,
#  1.0013828924548975,
#  1.0110306631060384,
#  1.00924317970872,
#  0.9972927532085558,
#  0.9919822237934429,
#  0.9971928350753095,
#  1.0052157734296276,
#  1.0036601666003713,
#  0.9970948629316029,
#  0.9953659432576489,
#  0.9974195877270805,
#  0.9961596867711601,
#  0.9999967427520251,
#  1.0033909151991345,
#  1.0013698047212232,
#  0.9978949758990464,
#  1.0002610255377475,
#  0.9980833332582104,
#  1.0003902622710268,
#  1.0021817359955147,
#  1.001927317143151,
#  1.0005452018700434,
#  0.9962480949023621,
#  1.0067741810347324,
#  1.0061660161000077,
#  1.0060881785317497,
#  1.0012089817971668,
#  1.0033929409095261,
#  1.0032135124453978,
#  0.993245986441494,
#  0.9998907726522284,
#  0.9960186345510791,
#  1.00744776225019,
#  1.007715097507133,
#  1.0088644045895394,
#  0.9988278565916882,
#  1.0108587146256396,
#  1.0006810989711046,
#  0.9968592845168547,
#  1.0012507465387517,
#  0.9960818244127965,
#  1.0010508161188028,
#  1.0109741333614317,
#  1.0101829101408903,
#  1.0131865578502737,
#  0.9835579680160287,
#  1.01692804990109,
#  1.001609306466996,
#  0.9939884146260439,
#  1.0067362578116186,
#  1.005065936269571,
#  1.0063523784022788,
#  1.0013397969938216,
#  0.9978030767410777,
#  1.009746366572401,
#  1.0053477106446966,
#  0.9959739679972577,
#  1.0099042508774647,
#  1.0002037637295016,
#  1.0007437589754165,
#  0.9777853765094114,
#  1.001271249500619,
#  1.0126638062332658,
#  1.0132763446825752,
#  1.0104365697056383,
#  1.0116850676779572]

# %%
type(test)
# Out:
# pandas.core.series.Series

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
#

# %%
train_input =np.arange(len(df_test.index))/252
train_target = np.array(list(df_test['Buy']))

# %%
train_input = train_input.reshape(-1,1)
# train_input

# %%
train_target = train_target.reshape(-1,1)
# train_target.shape

# %%
lr.fit(train_input, train_target)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[0.551704]])

# %%
lr.score(train_input,train_target)
# Out:
# 0.9330705853387796

# %%
import matplotlib.pyplot as plt
plt.scatter(train_input, train_target)

# %%
stock_buy_list = case1.make_stock_list_by_finance(fs=case1.finance_naver,date_buy=datetime(2021,8,26),volatility_factors=[]).head(50)
# Out:
# The date you entered 20200101 seems to be a holiday. PYKRX changes the date parameter to 20191230 to query the requested information.
# The date you entered 20201231 seems to be a holiday. PYKRX changes the date parameter to 20201230 to query the requested information.

# %%
stock_buy_list = stock_buy_list[stock_buy_list['Fscore']==3].head(30)['stock_code']

# %%
stocks_list, portion_list = case1.cal_portion_by_momentum_score_defensive(stocks=list(stock_buy_list),bgn=datetime(2021,8,26),end=datetime(2021,8,26))

# %%
total_asset = 100000000 # 천만원
# no_of_stocks = len(stock_buy_list) # 매수 종목 수
# asset_of_each_stock = int(total_asset / no_of_stocks) # 종목별 매수 금액
portfolio_stock_dict={}
total_buy = 0
# {종목코드 : {수량 : 2}}
for i in range(len(stocks_list)):
    if stocks_list[i] == 'cash':
        continue
    price = fdr.DataReader(stocks_list[i],start='2021-08-26',end='2021-08-26').iat[0,3]
    asset_of_each_stock = total_asset * portion_list[i]
    quantity = math.ceil(asset_of_each_stock/price)
    buy = price*quantity
    portfolio_stock_dict[stocks_list[i]] = {'수량':quantity}
    total_buy += buy
print(total_buy)
# Out:
# 69239090

# %%
with open('/Users/malko/PycharmProjects/xing/TradingPlan/trade_plan.pickle','wb') as handle:
    pickle.dump(portfolio_stock_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
for i in range(len(stocks_list)):
# Out:
# tuple

# %%
case1.dictPortfolio
# Out:
# {}

# %%
test.test()
# Out:
# 2012-04-15 00:00:00 2
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# new
# old
# 2012-05-15 00:00:00 모멘텀 종목 수 :  13
# 2012-06-15 00:00:00 3
# old
# 2012-06-15 00:00:00 모멘텀 종목 수 :  11
# old
# 2012-07-15 00:00:00 모멘텀 종목 수 :  15
# old
# 2012-08-15 00:00:00 모멘텀 종목 수 :  15
# 2012-09-15 00:00:00 3
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# old
# 2012-09-15 00:00:00 모멘텀 종목 수 :  22
# old
# 2012-10-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2012-11-15 00:00:00 모멘텀 종목 수 :  9
# 2012-12-15 00:00:00 4
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.
# old
# 2012-12-15 00:00:00 모멘텀 종목 수 :  12
# old
# 2013-01-15 00:00:00 모멘텀 종목 수 :  18
# old
# 2013-02-15 00:00:00 모멘텀 종목 수 :  12
# old
# 2013-03-15 00:00:00 모멘텀 종목 수 :  21
# 2013-04-15 00:00:00 2
# old
# 2013-04-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2013-05-15 00:00:00 모멘텀 종목 수 :  19
# 2013-06-15 00:00:00 3
# The date you entered 20130615 seems to be a holiday. PYKRX changes the date parameter to 20130614 to query the requested information.
# The date you entered 20130615 seems to be a holiday. PYKRX changes the date parameter to 20130614 to query the requested information.
# old
# 2013-06-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2013-07-15 00:00:00 모멘텀 종목 수 :  16
# old
# 2013-08-15 00:00:00 모멘텀 종목 수 :  18
# 2013-09-15 00:00:00 3
# The date you entered 20130915 seems to be a holiday. PYKRX changes the date parameter to 20130913 to query the requested information.
# The date you entered 20130915 seems to be a holiday. PYKRX changes the date parameter to 20130913 to query the requested information.
# old
# 2013-09-15 00:00:00 모멘텀 종목 수 :  8
# old
# 2013-10-15 00:00:00 모멘텀 종목 수 :  11
# old
# 2013-11-15 00:00:00 모멘텀 종목 수 :  13
# 2013-12-15 00:00:00 4
# The date you entered 20131215 seems to be a holiday. PYKRX changes the date parameter to 20131213 to query the requested information.
# The date you entered 20131215 seems to be a holiday. PYKRX changes the date parameter to 20131213 to query the requested information.
# old
# 2013-12-15 00:00:00 모멘텀 종목 수 :  8
# old
# 2014-01-15 00:00:00 모멘텀 종목 수 :  12
# old
# 2014-02-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2014-03-15 00:00:00 모멘텀 종목 수 :  12
# 2014-04-15 00:00:00 2
# old
# 2014-04-15 00:00:00 모멘텀 종목 수 :  14
# old
# 2014-05-15 00:00:00 모멘텀 종목 수 :  22
# 2014-06-15 00:00:00 3
# The date you entered 20140615 seems to be a holiday. PYKRX changes the date parameter to 20140613 to query the requested information.
# The date you entered 20140615 seems to be a holiday. PYKRX changes the date parameter to 20140613 to query the requested information.
# old
# 2014-06-15 00:00:00 모멘텀 종목 수 :  16
# old
# 2014-07-15 00:00:00 모멘텀 종목 수 :  22
# old
# 2014-08-15 00:00:00 모멘텀 종목 수 :  7
# 2014-09-15 00:00:00 3
# old
# 2014-09-15 00:00:00 모멘텀 종목 수 :  12
# old
# 2014-10-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2014-11-15 00:00:00 모멘텀 종목 수 :  11
# 2014-12-15 00:00:00 4
# old
# 2014-12-15 00:00:00 모멘텀 종목 수 :  13
# old
# 2015-01-15 00:00:00 모멘텀 종목 수 :  13
# old
# 2015-02-15 00:00:00 모멘텀 종목 수 :  20
# old
# 2015-03-15 00:00:00 모멘텀 종목 수 :  19
# 2015-04-15 00:00:00 2
# old
# 2015-04-15 00:00:00 모멘텀 종목 수 :  26
# old
# 2015-05-15 00:00:00 모멘텀 종목 수 :  16
# 2015-06-15 00:00:00 3
# old
# 2015-06-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2015-07-15 00:00:00 모멘텀 종목 수 :  18
# old
# 2015-08-15 00:00:00 모멘텀 종목 수 :  8
# 2015-09-15 00:00:00 3
# old
# 2015-09-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2015-10-15 00:00:00 모멘텀 종목 수 :  14
# old
# 2015-11-15 00:00:00 모멘텀 종목 수 :  4
# 2015-12-15 00:00:00 4
# old
# 2015-12-15 00:00:00 모멘텀 종목 수 :  5
# old
# 2016-01-15 00:00:00 모멘텀 종목 수 :  8
# old
# 2016-02-15 00:00:00 모멘텀 종목 수 :  3
# old
# 2016-03-15 00:00:00 모멘텀 종목 수 :  8
# 2016-04-15 00:00:00 2
# old
# 2016-04-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2016-05-15 00:00:00 모멘텀 종목 수 :  5
# 2016-06-15 00:00:00 3
# old
# 2016-06-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2016-07-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2016-08-15 00:00:00 모멘텀 종목 수 :  11
# 2016-09-15 00:00:00 3
# The date you entered 20160915 seems to be a holiday. PYKRX changes the date parameter to 20160913 to query the requested information.
# The date you entered 20160915 seems to be a holiday. PYKRX changes the date parameter to 20160913 to query the requested information.
# old
# 2016-09-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2016-10-15 00:00:00 모멘텀 종목 수 :  16
# old
# 2016-11-15 00:00:00 모멘텀 종목 수 :  7
# 2016-12-15 00:00:00 4
# old
# 2016-12-15 00:00:00 모멘텀 종목 수 :  8
# old
# 2017-01-15 00:00:00 모멘텀 종목 수 :  11
# old
# 2017-02-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2017-03-15 00:00:00 모멘텀 종목 수 :  13
# 2017-04-15 00:00:00 2
# The date you entered 20170415 seems to be a holiday. PYKRX changes the date parameter to 20170414 to query the requested information.
# The date you entered 20170415 seems to be a holiday. PYKRX changes the date parameter to 20170414 to query the requested information.
# old
# 2017-04-15 00:00:00 모멘텀 종목 수 :  5
# old
# 2017-05-15 00:00:00 모멘텀 종목 수 :  13
# 2017-06-15 00:00:00 3
# old
# 2017-06-15 00:00:00 모멘텀 종목 수 :  16
# old
# 2017-07-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2017-08-15 00:00:00 모멘텀 종목 수 :  4
# 2017-09-15 00:00:00 3
# old
# 2017-09-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2017-10-15 00:00:00 모멘텀 종목 수 :  5
# old
# 2017-11-15 00:00:00 모멘텀 종목 수 :  9
# 2017-12-15 00:00:00 4
# old
# 2017-12-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2018-01-15 00:00:00 모멘텀 종목 수 :  13
# old
# 2018-02-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2018-03-15 00:00:00 모멘텀 종목 수 :  8
# 2018-04-15 00:00:00 2
# The date you entered 20180415 seems to be a holiday. PYKRX changes the date parameter to 20180413 to query the requested information.
# The date you entered 20180415 seems to be a holiday. PYKRX changes the date parameter to 20180413 to query the requested information.
# old
# 2018-04-15 00:00:00 모멘텀 종목 수 :  7
# old
# 2018-05-15 00:00:00 모멘텀 종목 수 :  12
# 2018-06-15 00:00:00 3
# old
# 2018-06-15 00:00:00 모멘텀 종목 수 :  7
# old
# 2018-07-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2018-08-15 00:00:00 모멘텀 종목 수 :  9
# 2018-09-15 00:00:00 3
# The date you entered 20180915 seems to be a holiday. PYKRX changes the date parameter to 20180914 to query the requested information.
# The date you entered 20180915 seems to be a holiday. PYKRX changes the date parameter to 20180914 to query the requested information.
# old
# 2018-09-15 00:00:00 모멘텀 종목 수 :  18
# old
# 2018-10-15 00:00:00 모멘텀 종목 수 :  2
# old
# 2018-11-15 00:00:00 모멘텀 종목 수 :  1
# 2018-12-15 00:00:00 4
# The date you entered 20181215 seems to be a holiday. PYKRX changes the date parameter to 20181214 to query the requested information.
# The date you entered 20181215 seems to be a holiday. PYKRX changes the date parameter to 20181214 to query the requested information.
# old
# 2018-12-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2019-01-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2019-02-15 00:00:00 모멘텀 종목 수 :  12
# old
# 2019-03-15 00:00:00 모멘텀 종목 수 :  4
# 2019-04-15 00:00:00 2
# old
# 2019-04-15 00:00:00 모멘텀 종목 수 :  15
# old
# 2019-05-15 00:00:00 모멘텀 종목 수 :  7
# 2019-06-15 00:00:00 3
# The date you entered 20190615 seems to be a holiday. PYKRX changes the date parameter to 20190614 to query the requested information.
# The date you entered 20190615 seems to be a holiday. PYKRX changes the date parameter to 20190614 to query the requested information.
# old
# 2019-06-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2019-07-15 00:00:00 모멘텀 종목 수 :  3
# old
# 2019-08-15 00:00:00 모멘텀 종목 수 :  5
# 2019-09-15 00:00:00 3
# The date you entered 20190915 seems to be a holiday. PYKRX changes the date parameter to 20190911 to query the requested information.
# The date you entered 20190915 seems to be a holiday. PYKRX changes the date parameter to 20190911 to query the requested information.
# old
# 2019-09-15 00:00:00 모멘텀 종목 수 :  5
# old
# 2019-10-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2019-11-15 00:00:00 모멘텀 종목 수 :  11
# 2019-12-15 00:00:00 4
# The date you entered 20191215 seems to be a holiday. PYKRX changes the date parameter to 20191213 to query the requested information.
# The date you entered 20191215 seems to be a holiday. PYKRX changes the date parameter to 20191213 to query the requested information.
# old
# 2019-12-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2020-01-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2020-02-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2020-03-15 00:00:00 모멘텀 종목 수 :  0
# 2020-04-15 00:00:00 2
# The date you entered 20200415 seems to be a holiday. PYKRX changes the date parameter to 20200414 to query the requested information.
# The date you entered 20200415 seems to be a holiday. PYKRX changes the date parameter to 20200414 to query the requested information.
# old
# 2020-04-15 00:00:00 모멘텀 종목 수 :  4
# old
# 2020-05-15 00:00:00 모멘텀 종목 수 :  6
# 2020-06-15 00:00:00 3
# old
# 2020-06-15 00:00:00 모멘텀 종목 수 :  2
# old
# 2020-07-15 00:00:00 모멘텀 종목 수 :  14
# old
# 2020-08-15 00:00:00 모멘텀 종목 수 :  16
# 2020-09-15 00:00:00 3
# old
# 2020-09-15 00:00:00 모멘텀 종목 수 :  17
# old
# 2020-10-15 00:00:00 모멘텀 종목 수 :  11
# old
# 2020-11-15 00:00:00 모멘텀 종목 수 :  16
# 2020-12-15 00:00:00 4
# old
# 2020-12-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2021-01-15 00:00:00 모멘텀 종목 수 :  20
# old
# 2021-02-15 00:00:00 모멘텀 종목 수 :  15
# old
# 2021-03-15 00:00:00 모멘텀 종목 수 :  14
# withMomentumYear
#                     Buy      KOSPI
# Total Profit   3.301668   1.606237
# CAGR          14.560000   5.540000
# MDD          -24.729000 -43.819000
# Std           14.310000  15.430000
# Sharpe_Ratio   1.017470   0.359041

# %%
test.test()
# Out:
# 2012-04-15 00:00:00 2
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# The date you entered 20120415 seems to be a holiday. PYKRX changes the date parameter to 20120413 to query the requested information.
# new
# old
# 2012-05-15 00:00:00 모멘텀 종목 수 :  13
# 2012-06-15 00:00:00 3
# old
# 2012-06-15 00:00:00 모멘텀 종목 수 :  11
# old
# 2012-07-15 00:00:00 모멘텀 종목 수 :  15
# old
# 2012-08-15 00:00:00 모멘텀 종목 수 :  15
# 2012-09-15 00:00:00 3
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# The date you entered 20120915 seems to be a holiday. PYKRX changes the date parameter to 20120914 to query the requested information.
# old
# 2012-09-15 00:00:00 모멘텀 종목 수 :  22
# old
# 2012-10-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2012-11-15 00:00:00 모멘텀 종목 수 :  9
# 2012-12-15 00:00:00 4
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.
# The date you entered 20121215 seems to be a holiday. PYKRX changes the date parameter to 20121214 to query the requested information.
# old
# 2012-12-15 00:00:00 모멘텀 종목 수 :  12
# old
# 2013-01-15 00:00:00 모멘텀 종목 수 :  18
# old
# 2013-02-15 00:00:00 모멘텀 종목 수 :  13
# old
# 2013-03-15 00:00:00 모멘텀 종목 수 :  21
# 2013-04-15 00:00:00 2
# old
# 2013-04-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2013-05-15 00:00:00 모멘텀 종목 수 :  19
# 2013-06-15 00:00:00 3
# The date you entered 20130615 seems to be a holiday. PYKRX changes the date parameter to 20130614 to query the requested information.
# The date you entered 20130615 seems to be a holiday. PYKRX changes the date parameter to 20130614 to query the requested information.
# old
# 2013-06-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2013-07-15 00:00:00 모멘텀 종목 수 :  16
# old
# 2013-08-15 00:00:00 모멘텀 종목 수 :  18
# 2013-09-15 00:00:00 3
# The date you entered 20130915 seems to be a holiday. PYKRX changes the date parameter to 20130913 to query the requested information.
# The date you entered 20130915 seems to be a holiday. PYKRX changes the date parameter to 20130913 to query the requested information.
# old
# 2013-09-15 00:00:00 모멘텀 종목 수 :  8
# old
# 2013-10-15 00:00:00 모멘텀 종목 수 :  11
# old
# 2013-11-15 00:00:00 모멘텀 종목 수 :  13
# 2013-12-15 00:00:00 4
# The date you entered 20131215 seems to be a holiday. PYKRX changes the date parameter to 20131213 to query the requested information.
# The date you entered 20131215 seems to be a holiday. PYKRX changes the date parameter to 20131213 to query the requested information.
# old
# 2013-12-15 00:00:00 모멘텀 종목 수 :  8
# old
# 2014-01-15 00:00:00 모멘텀 종목 수 :  12
# old
# 2014-02-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2014-03-15 00:00:00 모멘텀 종목 수 :  13
# 2014-04-15 00:00:00 2
# old
# 2014-04-15 00:00:00 모멘텀 종목 수 :  14
# old
# 2014-05-15 00:00:00 모멘텀 종목 수 :  22
# 2014-06-15 00:00:00 3
# The date you entered 20140615 seems to be a holiday. PYKRX changes the date parameter to 20140613 to query the requested information.
# The date you entered 20140615 seems to be a holiday. PYKRX changes the date parameter to 20140613 to query the requested information.
# old
# 2014-06-15 00:00:00 모멘텀 종목 수 :  16
# old
# 2014-07-15 00:00:00 모멘텀 종목 수 :  22
# old
# 2014-08-15 00:00:00 모멘텀 종목 수 :  7
# 2014-09-15 00:00:00 3
# old
# 2014-09-15 00:00:00 모멘텀 종목 수 :  12
# old
# 2014-10-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2014-11-15 00:00:00 모멘텀 종목 수 :  11
# 2014-12-15 00:00:00 4
# old
# 2014-12-15 00:00:00 모멘텀 종목 수 :  13
# old
# 2015-01-15 00:00:00 모멘텀 종목 수 :  13
# old
# 2015-02-15 00:00:00 모멘텀 종목 수 :  20
# old
# 2015-03-15 00:00:00 모멘텀 종목 수 :  20
# 2015-04-15 00:00:00 2
# old
# 2015-04-15 00:00:00 모멘텀 종목 수 :  26
# old
# 2015-05-15 00:00:00 모멘텀 종목 수 :  16
# 2015-06-15 00:00:00 3
# old
# 2015-06-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2015-07-15 00:00:00 모멘텀 종목 수 :  18
# old
# 2015-08-15 00:00:00 모멘텀 종목 수 :  9
# 2015-09-15 00:00:00 3
# old
# 2015-09-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2015-10-15 00:00:00 모멘텀 종목 수 :  14
# old
# 2015-11-15 00:00:00 모멘텀 종목 수 :  4
# 2015-12-15 00:00:00 4
# old
# 2015-12-15 00:00:00 모멘텀 종목 수 :  5
# old
# 2016-01-15 00:00:00 모멘텀 종목 수 :  8
# old
# 2016-02-15 00:00:00 모멘텀 종목 수 :  3
# old
# 2016-03-15 00:00:00 모멘텀 종목 수 :  8
# 2016-04-15 00:00:00 2
# old
# 2016-04-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2016-05-15 00:00:00 모멘텀 종목 수 :  5
# 2016-06-15 00:00:00 3
# old
# 2016-06-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2016-07-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2016-08-15 00:00:00 모멘텀 종목 수 :  11
# 2016-09-15 00:00:00 3
# The date you entered 20160915 seems to be a holiday. PYKRX changes the date parameter to 20160913 to query the requested information.
# The date you entered 20160915 seems to be a holiday. PYKRX changes the date parameter to 20160913 to query the requested information.
# old
# 2016-09-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2016-10-15 00:00:00 모멘텀 종목 수 :  16
# old
# 2016-11-15 00:00:00 모멘텀 종목 수 :  7
# 2016-12-15 00:00:00 4
# old
# 2016-12-15 00:00:00 모멘텀 종목 수 :  8
# old
# 2017-01-15 00:00:00 모멘텀 종목 수 :  11
# old
# 2017-02-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2017-03-15 00:00:00 모멘텀 종목 수 :  13
# 2017-04-15 00:00:00 2
# The date you entered 20170415 seems to be a holiday. PYKRX changes the date parameter to 20170414 to query the requested information.
# The date you entered 20170415 seems to be a holiday. PYKRX changes the date parameter to 20170414 to query the requested information.
# old
# 2017-04-15 00:00:00 모멘텀 종목 수 :  5
# old
# 2017-05-15 00:00:00 모멘텀 종목 수 :  13
# 2017-06-15 00:00:00 3
# old
# 2017-06-15 00:00:00 모멘텀 종목 수 :  16
# old
# 2017-07-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2017-08-15 00:00:00 모멘텀 종목 수 :  4
# 2017-09-15 00:00:00 3
# old
# 2017-09-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2017-10-15 00:00:00 모멘텀 종목 수 :  5
# old
# 2017-11-15 00:00:00 모멘텀 종목 수 :  9
# 2017-12-15 00:00:00 4
# old
# 2017-12-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2018-01-15 00:00:00 모멘텀 종목 수 :  13
# old
# 2018-02-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2018-03-15 00:00:00 모멘텀 종목 수 :  8
# 2018-04-15 00:00:00 2
# The date you entered 20180415 seems to be a holiday. PYKRX changes the date parameter to 20180413 to query the requested information.
# The date you entered 20180415 seems to be a holiday. PYKRX changes the date parameter to 20180413 to query the requested information.
# old
# 2018-04-15 00:00:00 모멘텀 종목 수 :  7
# old
# 2018-05-15 00:00:00 모멘텀 종목 수 :  12
# 2018-06-15 00:00:00 3
# old
# 2018-06-15 00:00:00 모멘텀 종목 수 :  7
# old
# 2018-07-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2018-08-15 00:00:00 모멘텀 종목 수 :  9
# 2018-09-15 00:00:00 3
# The date you entered 20180915 seems to be a holiday. PYKRX changes the date parameter to 20180914 to query the requested information.
# The date you entered 20180915 seems to be a holiday. PYKRX changes the date parameter to 20180914 to query the requested information.
# old
# 2018-09-15 00:00:00 모멘텀 종목 수 :  18
# old
# 2018-10-15 00:00:00 모멘텀 종목 수 :  2
# old
# 2018-11-15 00:00:00 모멘텀 종목 수 :  1
# 2018-12-15 00:00:00 4
# The date you entered 20181215 seems to be a holiday. PYKRX changes the date parameter to 20181214 to query the requested information.
# The date you entered 20181215 seems to be a holiday. PYKRX changes the date parameter to 20181214 to query the requested information.
# old
# 2018-12-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2019-01-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2019-02-15 00:00:00 모멘텀 종목 수 :  12
# old
# 2019-03-15 00:00:00 모멘텀 종목 수 :  4
# 2019-04-15 00:00:00 2
# old
# 2019-04-15 00:00:00 모멘텀 종목 수 :  15
# old
# 2019-05-15 00:00:00 모멘텀 종목 수 :  8
# 2019-06-15 00:00:00 3
# The date you entered 20190615 seems to be a holiday. PYKRX changes the date parameter to 20190614 to query the requested information.
# The date you entered 20190615 seems to be a holiday. PYKRX changes the date parameter to 20190614 to query the requested information.
# old
# 2019-06-15 00:00:00 모멘텀 종목 수 :  9
# old
# 2019-07-15 00:00:00 모멘텀 종목 수 :  3
# old
# 2019-08-15 00:00:00 모멘텀 종목 수 :  5
# 2019-09-15 00:00:00 3
# The date you entered 20190915 seems to be a holiday. PYKRX changes the date parameter to 20190911 to query the requested information.
# The date you entered 20190915 seems to be a holiday. PYKRX changes the date parameter to 20190911 to query the requested information.
# old
# 2019-09-15 00:00:00 모멘텀 종목 수 :  5
# old
# 2019-10-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2019-11-15 00:00:00 모멘텀 종목 수 :  11
# 2019-12-15 00:00:00 4
# The date you entered 20191215 seems to be a holiday. PYKRX changes the date parameter to 20191213 to query the requested information.
# The date you entered 20191215 seems to be a holiday. PYKRX changes the date parameter to 20191213 to query the requested information.
# old
# 2019-12-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2020-01-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2020-02-15 00:00:00 모멘텀 종목 수 :  6
# old
# 2020-03-15 00:00:00 모멘텀 종목 수 :  0
# 2020-04-15 00:00:00 2
# The date you entered 20200415 seems to be a holiday. PYKRX changes the date parameter to 20200414 to query the requested information.
# The date you entered 20200415 seems to be a holiday. PYKRX changes the date parameter to 20200414 to query the requested information.
# old
# 2020-04-15 00:00:00 모멘텀 종목 수 :  3
# old
# 2020-05-15 00:00:00 모멘텀 종목 수 :  5
# 2020-06-15 00:00:00 3
# old
# 2020-06-15 00:00:00 모멘텀 종목 수 :  2
# old
# 2020-07-15 00:00:00 모멘텀 종목 수 :  14
# old
# 2020-08-15 00:00:00 모멘텀 종목 수 :  17
# 2020-09-15 00:00:00 3
# old
# 2020-09-15 00:00:00 모멘텀 종목 수 :  16
# old
# 2020-10-15 00:00:00 모멘텀 종목 수 :  10
# old
# 2020-11-15 00:00:00 모멘텀 종목 수 :  16
# 2020-12-15 00:00:00 4
# old
# 2020-12-15 00:00:00 모멘텀 종목 수 :  19
# old
# 2021-01-15 00:00:00 모멘텀 종목 수 :  20
# old
# 2021-02-15 00:00:00 모멘텀 종목 수 :  14
# old
# 2021-03-15 00:00:00 모멘텀 종목 수 :  13
# withMomentumYear
#                        Buy      KOSPI
# Total Profit  3.718732e+27   1.606237
# CAGR          1.373339e+05   5.540000
# MDD          -5.203000e+00 -43.819000
# Std           3.038800e+02  15.430000
# Sharpe_Ratio  4.519345e+02   0.359041

# %%
for i in list(test.dictPortfolio.keys()):
    print(i)
    print(test.dictPortfolio[i]['portion'][-1])
#     print(sum(test.dictPortfolio[i]['portion']))
# Out:
# 201204
# 0.23333333333333328
# 201205
# 0.25673604442425463
# 201206
# 0.2753901017153964
# 201207
# 0.31859662254347476
# 201208
# 0.36157370657783233
# 201209
# 0.23305987111905935
# 201210
# 0.22920239951218546
# 201211
# 0.29926316806243664
# 201212
# 0.1410875802978146
# 201301
# 0.16825485936370654
# 201302
# 0.22494521734098533
# 201303
# 0.19920933728114257
# 201304
# 0.11107808832251029
# 201305
# 0.13594208135408842
# 201306
# 0.12943067521505902
# 201307
# 0.18539809440071692
# 201308
# 0.21896507379667116
# 201309
# 0.2276134653504295
# 201310
# 0.3087944028762477
# 201311
# 0.34778648169154297
# 201312
# 0.33569789088339175
# 201401
# 0.3216753475327436
# 201402
# 0.3258269873685965
# 201403
# 0.3138743148285033
# 201404
# 0.13935894808194857
# 201405
# 0.1198796642483589
# 201406
# 0.1075050849698251
# 201407
# 0.07705415478862965
# 201408
# 0.15125434622150408
# 201409
# 0.14137743859688695
# 201410
# 0.22370928226083758
# 201411
# 0.34931505849588695
# 201412
# 0.24498219737199978
# 201501
# 0.3241187723649532
# 201502
# 0.3240886856971634
# 201503
# 0.29698908576969546
# 201504
# 0.2160747725236979
# 201505
# 0.17907917501786078
# 201506
# 0.19159859860451256
# 201507
# 0.24268491061492556
# 201508
# 0.2680729237128085
# 201509
# 0.30169907314017574
# 201510
# 0.32249843930723765
# 201511
# 0.4412092967310888
# 201512
# 0.5073873181074341
# 201601
# 0.5378231098976389
# 201602
# 0.6801583828752362
# 201603
# 0.5531265748582644
# 201604
# 0.31706391737140177
# 201605
# 0.3398497559867945
# 201606
# 0.2844842638945967
# 201607
# 0.2899676046749067
# 201608
# 0.2607164169496118
# 201609
# 0.2634187472881674
# 201610
# 0.2978269487986174
# 201611
# 0.48605300470102775
# 201612
# 0.38198352159106513
# 201701
# 0.3732239722164169
# 201702
# 0.39216589284308323
# 201703
# 0.4058642157659654
# 201704
# 0.4513039297140037
# 201705
# 0.379923648678346
# 201706
# 0.27458049217112585
# 201707
# 0.3290257895057845
# 201708
# 0.4147862679509835
# 201709
# 0.2683574846108281
# 201710
# 0.38288200280584994
# 201711
# 0.42342187866406045
# 201712
# 0.37501302900767447
# 201801
# 0.3483840053803165
# 201802
# 0.41337104930781127
# 201803
# 0.43842968549036093
# 201804
# 0.3661133847059286
# 201805
# 0.3773991991846705
# 201806
# 0.20905973659989693
# 201807
# 0.2759032394595463
# 201808
# 0.41988345938151667
# 201809
# 0.30692038244951775
# 201810
# 0.5828204441773884
# 201811
# 0.6843154625290523
# 201812
# 0.5670261137311676
# 201901
# 0.5158351487838164
# 201902
# 0.42274234196269894
# 201903
# 0.4701523789390583
# 201904
# 0.3036669867538698
# 201905
# 0.3551483394042625
# 201906
# 0.35442755040576124
# 201907
# 0.519002882302638
# 201908
# 0.6842452322801368
# 201909
# 0.4321663381425992
# 201910
# 0.48549694235265106
# 201911
# 0.42911350630959033
# 201912
# 0.525656186081005
# 202001
# 0.4746555303547548
# 202002
# 0.504403739389759
# 202003
# 0.8774947284167885
# 202004
# 0.7621833658872091
# 202005
# 0.5500668102654389
# 202006
# 0.4727378289118473
# 202007
# 0.3460997369914295
# 202008
# 0.27419413576989454
# 202009
# 0.13533261830352816
# 202010
# 0.19259858083556264
# 202011
# 0.189090353311228
# 202012
# 0.14653949828312474
# 202101
# 0.18827781869963608
# 202102
# 0.18959699117421755
# 202103
# 0.22908766326960472

# %%
[0]*3
# Out:
# [0, 0, 0]
